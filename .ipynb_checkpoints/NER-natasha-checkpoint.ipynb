# %%
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    LOC,
    NamesExtractor,
    DatesExtractor,
    MoneyExtractor,
    AddrExtractor,

    Doc
)

segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)
dates_extractor = DatesExtractor(morph_vocab)
money_extractor = MoneyExtractor(morph_vocab)
addr_extractor = AddrExtractor(morph_vocab)

# %%
import codecs
fileObj = codecs.open( "C:/Users/Влад/Documents/Мое все/кодинг/статья.txt", "r", "utf_8_sig" )
text = fileObj.read()

# %%
text
# Out:
# 'Есть особая прелесть в британских таблоидах — в них всегда найдется, чем можно удовлетворить самые причудливые прихоти читателей. За сюжетом о британце из Уэльса, убившем собственную мать, идет рассказ о смерти бывшего футболиста и порноактера. Затем новости об изменениях в меню сети "Макдоналдс". Сразу после этих шокирующих вестей — заметка о телеведущей, опубликовавшей фото без лифчика. И далее в таком же роде. Пролистав интернет-страницу почти до самого конца и шапочно познакомившись с сюжетами из повседневной жизни британской желтой прессы, самые изощренные перверты смогут найти то, ради чего сюда пришли: интервью Зеленского для The Sun.\r\nДля особо искушенных даже есть видеоверсия. Правда, придется пробираться через насилие над английским языком, которым украинский лидер увлеченно занимается на протяжении 15 минут. Право слово, можно было бы отнестись к языку спонсоров более щадяще. Но выпускник Криворожского экономического института, волею судеб оказавшийся в кресле президента, за почти два года так и не справился с этой непосильной задачей — журналист даже подсказывает ему фразу "разжечь пожар".\r\nЗато в текстовой версии британский таблоид щедр на эпитеты. Самого Зеленского называют "львиным сердцем" — ни больше ни меньше. Короткое интервью в основном посвящено самой персоне украинского лидера, нежели делам в его стране. Вот он рассказывает про успешно пережитые шесть покушений, про парашютистов в Киеве, отправленных убить его, про баррикады в офисе на Банковой и так далее. Про нужды фронта — короткие реплики в духе "есть ПВО — дай", про ситуацию на фронте — "никакого тупика нет", про самих украинцев — "все устали, но переговоров не хотят".\r\nНо раз господин Зеленский так хорошо осведомлен о желаниях украинцев, то почему он отказывается проводить выборы? Неужто "контрнаступы" не вдохновили народ и поддержка упала до минимума? Или избирателям не по душе инициативы, о которых российской СВР стало известно в понедельник? Напомним, что речь идет о мобилизации украинцев до 65 лет в рядовой состав и до 70 — в командный. Параллельно планируется также снизить минимальный призывной возраст до 17 лет. Что ж, на фоне сентябрьских инициатив по призыву женщин в ВСУ, такой шаг никого бы не удивил. Тем более на фоне скудеющей поддержки со стороны Запада.\r\nЗа неделю в Киеве побывали и директор ЦРУ Уильям Бернс, и глава Пентагона Ллойд Остин. Последний даже привез обещания новых траншей военной помощи. Правда, пока вместо обещанного пакета на 105 миллиардов долларов помощи Киеву и Тель-Авиву ВСУ получат техники и боеприпасов всего на 100 миллионов. В том числе целый один комплекс HIMARS. Такими темпами Зеленский скоро будет встречать западных гостей на перроне Киева-Пассажирского и принимать у них клетчатые челночные сумки: "Что поместилось, то и привезли. Воюйте".\r\nНо приезжали не только американцы — был и глава Европейского совета Шарль Мишель, и министр обороны Германии Борис Писториус, а до них — новоиспеченный министр иностранных дел Британии и бывший ее же премьер Дэвид Кэмерон. И такая вереница высокопоставленных гостей, которые по меркам предыдущих поставок вооружений приезжают чуть ли не с пустыми руками, говорит о тревожных для Зеленского переменах в стратегии Запада на Украине: спонсоры наигрались в "контрнаступ" с новой техникой, пришло время обороны с тем, что есть.\r\nНо такие изменения не могут радовать Зеленского. Во-первых, это означает признание невозможности победы над Россией на поле боя. А ведь именно ему была отведена роль человека, который должен был убедить всех — в первую очередь украинских, европейских и американских обывателей — в том, что ВСУ на это способны. Поэтому он и опасается выборов — избиратель еще помнит обещания реляций о выходе к Азовскому морю. Но увы, до берега этого (теперь уже внутреннего российского) моря от Работино далековато. И теперь, раз победа невозможна, ради чего 65-летние пенсионеры на пару с 17-летними подростками должны идти на фронт? Чтобы отсрочить неизбежное?\r\nВот Зелен ...

# %%
doc = Doc(text)
doc.segment(segmenter) 
doc.tag_morph(morph_tagger)
doc.parse_syntax(syntax_parser)
doc.tag_ner(ner_tagger)

# %%
doc.segment(segmenter)
display(doc.tokens[:5])
# Out:
# [DocToken(stop=4, text='Есть'),
#  DocToken(start=5, stop=11, text='особая'),
#  DocToken(start=12, stop=20, text='прелесть'),
#  DocToken(start=21, stop=22, text='в'),
#  DocToken(start=23, stop=33, text='британских')]

# %%
display(doc.sents[:5])
# Out:
# [DocSent(stop=129, text='Есть особая прелесть в британских таблоидах — в н..., tokens=[...]),
#  DocSent(start=130, stop=244, text='За сюжетом о британце из Уэльса, убившем собствен..., tokens=[...]),
#  DocSent(start=245, stop=298, text='Затем новости об изменениях в меню сети "Макдонал..., tokens=[...]),
#  DocSent(start=299, stop=391, text='Сразу после этих шокирующих вестей — заметка о те..., tokens=[...]),
#  DocSent(start=392, stop=416, text='И далее в таком же роде.', tokens=[...])]

# %%
#Морфологический разбор отдельных слов(существительное, глагол и тд)
doc.tag_morph(morph_tagger)
display(doc.tokens[:5])
# Out:
# [DocToken(stop=4, text='Есть', pos='VERB', feats=<Imp,Ind,Sing,3,Pres,Fin,Act>),
#  DocToken(start=5, stop=11, text='особая', pos='ADJ', feats=<Nom,Pos,Fem,Sing>),
#  DocToken(start=12, stop=20, text='прелесть', pos='NOUN', feats=<Inan,Nom,Fem,Sing>),
#  DocToken(start=21, stop=22, text='в', pos='ADP'),
#  DocToken(start=23, stop=33, text='британских', pos='ADJ', feats=<Loc,Pos,Plur>)]

# %%
for span in doc.spans:
    span.normalize(morph_vocab)

{_.text: _.normal for _ in doc.spans if _.text != _.normal}
# Out:
# {'Уэльса': 'Уэльс',
#  'Зеленского': 'Зеленский',
#  'Криворожского экономического института': 'Криворожский экономический институт',
#  'Киеве': 'Киев',
#  'Запада': 'Запад',
#  'Пентагона': 'Пентагон',
#  'Киеву': 'Киев',
#  'Тель-Авиву ВСУ': 'Тель-Авив ВСУ',
#  'Европейского совета': 'Европейский совет',
#  'Германии': 'Германия',
#  'Британии': 'Британия',
#  'Украине': 'Украина',
#  'Россией': 'Россия',
#  'Азовскому морю': 'Азовское море'}

# %%
#лемматизация
for token in doc.tokens:
    token.lemmatize(morph_vocab)
    
{_.text: _.lemma for _ in doc.tokens}
# Out:
# {'Есть': 'быть',
#  'особая': 'особый',
#  'прелесть': 'прелесть',
#  'в': 'в',
#  'британских': 'британский',
#  'таблоидах': 'таблоид',
#  '—': '—',
#  'них': 'они',
#  'всегда': 'всегда',
#  'найдется': 'найтись',
#  ',': ',',
#  'чем': 'чем',
#  'можно': 'можно',
#  'удовлетворить': 'удовлетворить',
#  'самые': 'самый',
#  'причудливые': 'причудливый',
#  'прихоти': 'прихоть',
#  'читателей': 'читатель',
#  '.': '.',
#  'За': 'за',
#  'сюжетом': 'сюжет',
#  'о': 'о',
#  'британце': 'британец',
#  'из': 'из',
#  'Уэльса': 'уэльс',
#  'убившем': 'убить',
#  'собственную': 'собственный',
#  'мать': 'мать',
#  'идет': 'идти',
#  'рассказ': 'рассказ',
#  'смерти': 'смерть',
#  'бывшего': 'бывший',
#  'футболиста': 'футболист',
#  'и': 'и',
#  'порноактера': 'порноактер',
#  'Затем': 'затем',
#  'новости': 'новость',
#  'об': 'о',
#  'изменениях': 'изменение',
#  'меню': 'меню',
#  'сети': 'сеть',
#  '"': '"',
#  'Макдоналдс': 'макдоналдс',
#  'Сразу': 'сразу',
#  'после': 'после',
#  'этих': 'этот',
#  'шокирующих': 'шокировать',
#  'вестей': 'весть',
#  'заметка': 'заметка',
#  'телеведущей': 'телеведущий',
#  'опубликовавшей': 'опубликовать',
#  'фото': 'фото',
#  'без': 'без',
#  'лифчика': 'лифчик',
#  'И': 'и',
#  'далее': 'далее',
#  'таком': 'такой',
#  'же': 'же',
#  'роде': 'род',
#  'Пролистав': 'пролистав',
#  'интернет-страницу': 'интернет-страница',
#  'почти': 'почти',
#  'до': 'до',
#  'самого': 'сам',
#  'конца': 'конец',
#  'шапочно': 'шапочный',
#  'познакомившись': 'познакомившись',
#  'с': 'с',
#  'сюжетами': 'сюжет',
#  'повседневной': 'повседневный',
#  'жизни': 'жизнь',
#  'британской': 'британский',
#  'желтой': 'желтый',
#  'прессы': 'пресса',
#  'изощренные': 'изощренный',
#  'перверты': 'перверт',
#  'смогут': 'смочь',
#  'найти': 'найти',
#  'то': 'то',
#  'ради': 'ради',
#  'чего': 'что',
#  'сюда': 'сюда',
#  'пришли': 'прийти',
#  ':': ':',
#  'интервью': 'интервью',
#  'Зеленского': 'зеленский',
#  'для': 'для',
#  'The': 'the',
#  'Sun': 'sun',
#  'Для': 'для',
#  'особо': 'особо',
#  'искушенных': 'искушенный',
#  'даже': 'даже',
#  'есть': 'быть',
#  'видеоверсия': 'видеоверсия',
#  'Правда': 'правда',
#  'придется': 'прийтись',
#  'пробираться': 'пробираться',
#  'через': 'через',
#  'насилие': 'насилие',
#  'над': 'над',
#  'английским': 'английский',
#  'языком': 'язык',
#  'которым': 'который',
#  'украинский': 'украинский',
#  'лидер': 'лидер',
#  'увлеченно': 'увлеченно',
#  'занимается': 'заниматься',
#  'на': 'на',
#  'протяжении': 'протяжение',
#  '15': '15',
#  'минут': 'минута',
#  'Право': 'право',
#  'слово': 'слово',
#  'было': 'быть',
#  'бы': 'бы',
#  'отнестись': 'отнестись',
#  'к': 'к',
#  'языку': 'язык',
#  'спонсоров': 'спонсор',
#  'более': 'более',
#  'щадяще': 'щадящий',
#  'Но': 'но',
#  'выпускник': 'выпускник',
#  'Криворожского': 'криворожский',
#  'экономического': 'экономический',
#  'института': 'институт',
#  'волею': 'воля',
#  'судеб': 'судьба',
#  'оказавшийся': 'оказаться',
#  'кресле': 'кресло',
#  'президента': 'президент',
#  'за': 'за',
#  'два': 'два',
#  'года': 'год',
#  'так': 'так',
#  'не': 'не',
#  'справился': 'справиться',
#  'этой': 'этот',
#  'непосильной': 'непосильный',
#  'задачей': 'задача',
#  'журналист': 'журналист',
#  'подсказывает': 'подсказывать',
#  'ему': 'он',
#  'фразу': 'фраза',
#  'разжечь': 'разжечь',
#  'пожар': 'пожар',
#  'Зато': 'зато',
#  'текстовой': 'текстовый',
#  'версии': 'версия',
#  'британский': 'британский',
#  'таблоид': 'таблоид',
#  'щедр': 'щедрый',
#  'эпитеты': 'эпитет',
#  'Самого': 'сам',
#  'называют': 'называть',
#  'львиным': 'львиный',
#  'сердцем': 'сердце',
#  'ни': 'ни',
#  'больше': 'большой',
#  'меньше': 'меньше',
#  'Короткое': 'короткий',
#  'основном': 'основный',
#  'посвящено': 'посвятить',
#  'самой': 'сам',
#  'персоне': 'персона',
#  'украинского': 'украинский',
#  'лидера': 'лидер',
#  'нежели': 'нежели',
#  'делам': 'дело',
#  'его': 'он',
#  'стране': 'страна',
#  'Вот': 'вот',
#  'он': 'он',
#  'рассказывает': 'рассказывать',
#  'про': 'про',
#  'успешно': 'успешно',
#  'пережитые': 'пережить',
#  'шесть': 'шесть',
#  'покушений': 'покушение',
#  'парашютистов': 'парашютист',
#  'Киеве': 'киев',
#  'отправленных': 'отправить',
#  'убить': 'убить',
#  'баррикады': 'баррикада',
#  'офисе': 'офис',
#  'Банковой': 'банковый',
#  'Про': 'про',
#  'нужды': 'нужда',
#  'фронта': 'фронт',
#  'короткие': 'короткий',
#  'реплики': 'реплика',
#  'духе': 'дух',
#  'ПВО': 'пво',
#  'дай': 'дать',
#  'ситуацию': 'ситуация',
#  'фронте': 'фронт',
#  'никакого': 'никакой',
#  'тупика': 'тупик',
#  'нет': 'нет',
#  'самих': 'сам',
#  'украинцев': 'украинец',
#  'все': 'весь',
#  'устали': 'усталь',
#  'но': 'но',
#  'переговоров': 'переговоры',
#  'хотят': 'хотеть',
#  'раз': 'раз',
#  'господин': 'господин',
#  'Зеленский': 'зеленский',
#  'хорошо': 'хорошо',
#  'осведомлен': 'осведомить',
#  'желаниях': 'желание',
#  'почему': 'почему',
#  'отказывается': 'отказываться',
#  'проводить': 'проводить',
#  'выборы': 'выбор',
#  '?': '?',
#  'Неужто': 'неужто',
#  'контрнаступы': 'контрнаступ',
#  'вдохновили': 'вдохновить',
#  'народ': 'народ',
#  'поддержка': 'поддержка',
#  'упала': 'упасть',
#  'минимума': 'минимум',
#  'Или': 'или',
#  'избирателям': 'избиратель',
#  'по': 'по',
#  'душе': 'душа',
#  'инициативы': 'инициатива',
#  'которых': 'который',
#  'российской': 'российский',
#  'СВР': 'свр',
#  'стало': 'стать',
#  'известно': 'известный',
#  'понедельник': 'понедельник',
#  'Напомним': 'напомнить',
#  'что': 'что',
#  'речь': 'речь',
#  'мобилизации': 'мобилизация',
#  '65': '65',
#  'лет': 'год',
#  'рядовой': 'рядовой',
#  'состав': 'состав',
#  '70': '70',
#  'командный': 'командный',
#  'Параллельно': 'параллельно',
#  'планируется': 'планироваться',
#  'также': 'также',
#  'снизить': 'снизить',
#  'минимальный': 'минимальный',
#  'призывной': 'призывной',
#  'возраст': 'возраст',
#  '17': '17',
#  'Что': 'что',
#  'ж': 'ж',
#  'фоне': 'фон',
#  'сентябрьских': 'сентябрьский',
#  'инициатив': 'инициатива',
#  'призыву': 'призыв',
#  'женщин': 'женщина',
#  'ВСУ': 'всу',
#  'такой': 'такой',
#  'шаг': 'шаг',
#  'никого': 'никто',
#  'удивил': 'удивить',
#  'Тем': 'тот',
#  'скудеющей': 'скудеть',
#  'поддержки': 'поддержка',
#  'со': 'с',
#  'стороны': 'сторона',
#  'Запада': 'запад',
#  'неделю': 'неделя',
#  'побывали': 'побывать',
#  'директор': 'директор',
#  'ЦРУ': 'цру',
#  'Уильям': 'уильям',
#  'Бернс': 'бернс',
#  'глава': 'глава',
#  'Пентагона': 'пентагон',
#  'Ллойд': 'ллойда',
#  'Остин': 'остин',
#  'Последний': 'последний',
#  'привез': 'привезти',
#  'обещания': 'обещание',
#  'новых': 'новый',
#  'траншей': 'траншея',
#  'военной': 'военный',
#  'помощи': 'помощь',
#  'пока': 'пока',
#  'вместо': 'вместо',
#  'обещанного': 'обещать',
#  'пакета': 'пакет',
#  '105': '105',
#  'миллиардов': 'миллиард',
#  'долларов': 'доллар',
#  'Киеву': 'киев',
#  'Тель-Авиву': 'тель-авив',
#  'получат': 'получить',
#  'техники': 'техник',
#  'боеприпасов': 'боеприпас',
#  'всего': 'всего',
#  '100': '100',
#  'миллионов': 'миллион',
#  'В': 'в',
#  'том': 'тот',
#  'числе': 'число',
#  'целый': 'целый',
#  'один': 'один',
#  'комплекс': 'комплекс',
#  'HIMARS': 'himars',
#  'Такими': 'такой',
#  'темпами': 'темп',
#  'скоро': 'скоро',
#  'будет': 'быть',
#  'встречать': 'встречать',
#  'западных': 'западный',
#  'гостей': 'гость',
#  'перроне': 'перрон',
#  'Киева-Пассажирского': 'киева-пассажирский',
#  'принимать': 'принимать',
#  'у': 'у',
#  'клетчатые': 'клетчатый',
#  'челночные': 'челночный',
#  'сумки': 'сумка',
#  'поместилось': 'поместиться',
#  'привезли': 'привезти',
#  'Воюйте': 'воевать',
#  'приезжали': 'приезжать',
#  'только': 'только',
#  'американцы': 'американец',
#  'был': 'быть',
#  'Европейского': 'европейский',
#  'совета': 'совет',
#  'Шарль': 'шарль',
#  'Мишель': 'мишель',
#  'министр': 'министр',
#  'обороны': 'оборона',
#  'Германии': 'германия',
#  'Борис': 'борис',
#  'Писториус': 'писториус',
#  'а': 'а',
#  'новоиспеченный': 'новоиспеченный',
#  'иностранных': 'иностранный',
#  'дел': 'дело',
#  'Британии': 'британия',
#  'бывший': 'бывший',
#  'ее': 'она',
#  'премьер': 'премьер',
#  'Дэвид': 'дэвид',
#  'Кэмерон': 'кэмерон',
#  'такая': 'такой',
#  'вереница': 'вереница',
#  'высокопоставленных': 'высокопоставленный',
#  'которые': 'который',
#  'меркам': 'мерка',
#  'предыдущих': 'предыдущий',
#  'поставок': 'поставка',
#  'вооружений': 'вооружение',
#  'приезжают': 'приезжать',
#  'чуть': 'чуть',
#  'ли': 'ли',
#  'пустыми': 'пустой',
#  'руками': 'рука',
#  'говорит': 'говорить',
#  'тревожных': 'тревожный',
#  'переменах': 'перемена',
#  'стратегии': 'стратегия',
#  'Украине': 'украина',
#  'спонсоры': 'спонсор',
#  'наигрались': 'наиграться',
#  'контрнаступ': 'контрнаступ',
#  'новой': 'новый',
#  'техникой': 'техника',
#  'пришло': 'прийти',
#  'время': 'время',
#  'тем': 'тот',
#  'такие': 'такой',
#  'изменения': 'изменение',
#  'могут': 'мочь',
#  'радовать': 'радовать',
#  'Во-первых': 'во-первых',
#  'это': 'это',
#  'означает': 'означать',
#  'признание': 'признание',
#  'невозможности': 'невозможность',
#  'победы': 'победа',
#  'Россией': 'россия',
#  'поле': 'поле',
#  'боя': 'бой',
#  'А': 'а',
#  'ведь': 'ведь',
#  'именно': 'именно',
#  'была': 'быть',
#  'отведена': 'отвести',
#  'роль': 'роль',
#  'человека': 'человек',
#  'который': 'который',
#  'должен': 'должный',
#  'убедить': 'убедить',
#  'всех': 'весь',
#  'первую': 'первый',
#  'очередь': 'очередь',
#  'украинских': 'украинский',
#  'европейских': 'европейский',
#  'американских': 'американский',
#  'обывателей': 'обыватель',
#  'способны': 'способный',
#  'Поэтому': 'поэтому',
#  'опасается': 'опасаться',
#  'выборов': 'выбор',
#  'избиратель': 'избиратель',
#  'еще': 'еще',
#  'помнит': 'помнить',
#  'реляций': 'реляция',
#  'выходе': 'выход',
#  'Азовскому': 'азовский',
#  'морю': 'море',
#  'увы': 'ува',
#  'берега': 'берег',
#  'этого': 'это',
#  '(': '(',
#  'теперь': 'теперь',
#  'уже': 'уже',
#  'внутреннего': 'внутренний',
#  'российского': 'российский',
#  ')': ')',
#  'моря': 'море',
#  'от': 'от',
#  'Работино': 'работин',
#  'далековато': 'далековатый',
#  'победа': 'победа',
#  'невозможна': 'невозможный',
#  '65-летние': '65-летний',
#  'пенсионеры': 'пенсионер',
#  'пару': 'пара',
#  '17-летними': '17-летними',
#  'подростками': 'подросток',
#  'должны': 'должный',
#  'идти': 'идти',
#  'фронт': 'фронт',
#  'Чтобы': 'чтобы',
#  'отсрочить': 'отсрочить',
#  'неизбежное': 'неизбежный',
#  'Россия': 'россия',
#  'пытается': 'пытаться',
#  'организовать': 'организовать',
#  'очередной': 'очередной',
#  'Майдан': 'майдан',
#  'десятую': 'десятый',
#  'годовщину': 'годовщина',
#  'начала': 'начало',
#  'революции': 'революция',
#  'достоинства': 'достоинство',
#  '!': '!',
#  'парадокс': 'парадокс',
#  'режим': 'режим',
#  'плоть': 'плоть',
#  'плоти': 'плоть',
#  'переворота': 'переворот',
#  'кружевных': 'кружевной',
#  'трусиков': 'трусик',
#  'ЕС': 'ес',
#  'как': 'как',
#  'огня': 'огонь',
#  'боится': 'бояться',
#  'своего': 'свой',
#  'прародителя': 'прародитель',
#  'народная': 'народный',
#  'демократия': 'демократия',
#  'На': 'на',
#  'этом': 'этот',
#  'понятно': 'понятный',
#  'согласился': 'согласиться',
#  'бульварной': 'бульварный',
#  'прессе': 'пресса',
#  'обживается': 'обживаться',
#  'светской': 'светский',
#  'хронике': 'хроника',
#  'Там': 'там',
#  'самое': 'самый',
#  'место': 'место',
#  'бывшему': 'бывший',
#  'президенту': 'президент',
#  'актеру': 'актер',
#  'Если': 'если',
#  'конечно': 'конечно',
#  'свои': 'свой',
#  'доберутся': 'добраться'}

# %%
#может искать даты, но я не нашел норм статью с датами
matches = dates_extractor(text)
facts = [i.fact.as_json for i in matches]
facts
# Out:
# []

# %%
for f in facts:
    print(f"{f.get('day')}.{f.get('month')}.{f.get('year')}")

# %%
for span in doc.spans:
    if span.type == PER:
        span.extract_fact(names_extractor)

names_dict = {_.normal: _.fact.as_dict for _ in doc.spans if _.fact}
names_dict
# Out:
# {'Зеленский': {'last': 'Зеленский'},
#  'Уильям Бернс': {'first': 'Уильям', 'last': 'Бернс'},
#  'Ллойд Остин': {'first': 'Остин', 'last': 'Ллойд'},
#  'Шарль Мишель': {'first': 'Шарль', 'last': 'Мишель'},
#  'Борис Писториус': {'first': 'Борис', 'last': 'Писториус'},
#  'Дэвид Кэмерон': {'first': 'Дэвид', 'last': 'Кэмерон'}}

# %%
list(names_dict.keys())
# Out:
# ['Зеленский',
#  'Уильям Бернс',
#  'Ллойд Остин',
#  'Шарль Мишель',
#  'Борис Писториус',
#  'Дэвид Кэмерон']
